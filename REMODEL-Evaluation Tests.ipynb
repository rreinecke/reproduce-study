# %%
import plot_all as all
all.all()

# %%
import process_data as data
data.process()
# Out:
# <bound method NDFrame.head of     CASE  SERIAL  REF QUESTNNR       MODE              STARTED  DM01  DM02_01  \
# 0     82     NaN  NaN     base  interview  2021-02-02 10:39:41     4        8
# 1     84     NaN  NaN     base  interview  2021-02-02 10:51:22     2        2
# 2     89     NaN  NaN     base  interview  2021-02-02 11:00:31     6        3
# 3     91     NaN  NaN     base  interview  2021-02-02 11:16:54     2        6
# 4     92     NaN  NaN     base  interview  2021-02-02 11:17:01     1       20
# 5     93     NaN  NaN     base  interview  2021-02-02 11:23:12     5       30
# 6     96     NaN  NaN     base  interview  2021-02-02 11:38:10     6        0
# 7    114     NaN  NaN     base  interview  2021-02-02 11:49:41     3        5
# 8    115     NaN  NaN     base  interview  2021-02-02 12:12:21     3       10
# 9    116     NaN  NaN     base  interview  2021-02-04 10:26:10     2        5
# 10   118     NaN  NaN     base  interview  2021-02-05 08:13:45     5       20
#
# ...
